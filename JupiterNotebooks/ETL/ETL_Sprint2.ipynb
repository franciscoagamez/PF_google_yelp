# %% [markdown]
# # ETL - Sprint #2
#
# Desarrolla el tratamiento de los datos con el fin de preparar los datos para la siguiente etapa (visualización, machine learning, etc.)

# %% [markdown]
# # 1. Instalación de librerías

# %%
# Dependencias
import os
import pandas as pd
import ast
from IPython.display import display
import geopandas as gpd
from shapely.geometry import Point
from shapely.geometry import mapping
import dask.dataframe as dd
import pyarrow as pa
import pyarrow.parquet as pq
import glob
import json

# %% [markdown]
# # 2. Preparación y limpieza del dataset metadata_sitios de Google
# <a id="1-Analisis-Google"></a>

# %% [markdown]
# ## a. Junta y revisa todos los archivos json (metadata_sitios)

# %%
# Define la ruta de la carpeta principal donde se encuentran los archivos JSON
main_folder = r'G:\My Drive\HENRY\PROYECTO_FINAL\ORIGINALES\GoogleMaps_local\Google Maps\metadata-sitios'

# Busca todos los archivos JSON en la carpeta principal y subcarpetas
all_json_files = glob.glob(os.path.join(main_folder, '**', '*.json'), recursive=True)

# Cargar los archivos JSON en un DataFrame de Dask
ddf = dd.read_json(all_json_files, blocksize='64MB')  # Ajusta el blocksize según sea necesario

# Convertir a un DataFrame de pandas para análisis adicional
metadata_sitios = ddf.compute()

# Mostrar el DataFrame combinado
print(metadata_sitios)
# Out:
#                                      name  \
# 0                         Porter Pharmacy
# 1                          Mcguinns store
# 2                   Gentle Hands Grooming
# 3      Smokecignals Electronic Cigarettes
# 4         Advanced Home Medical Equipment
# ...                                   ...
# 68357       Queen City Optical Provisions
# 68358               L & S Auto Repair Inc
# 68359             Denver Pet Sitters Inc.
# 68360      Summit Security Services, Inc.
# 68361                         Lane Bryant
#
#                                                  address  \
# 0      Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1       Mcguinns store, 4884 NC-9, Mill Spring, NC 28756
# 2      Gentle Hands Grooming, 156 US-176, Saluda, NC ...
# 3      Smokecignals Electronic Cigarettes, 2108 W Tho...
# 4      Advanced Home Medical Equipment, 885 Franklin ...
# ...                                                  ...
# 68357  Queen City Optical Provisions, 4321 W 44th Ave...
# 68358  L & S Auto Repair Inc, 222 Valentine Ln, Yonke...
# 68359  Denver Pet Sitters Inc., 3200 Lowell Blvd, Den...
# 68360  Summit Security Services, Inc., 280 N Central ...
# 68361     Lane Bryant, 196 Falon Lane, Altoona, PA 16602
#
#                                      gmap_id  \
# 0      0x88f16e41928ff687:0x883dad4fd048e8f8
# 1      0x88575f0654bd7c03:0xca3e467f7e766ad5
# 2      0x8859db7fe56d01c7:0xf90f3bdb3c62ba47
# 3      0x862722f489700e87:0x62c847c188bd5aa9
# 4      0x88523ca20145acc7:0x4b61a60bdc7d641e
# ...                                      ...
# 68357  0x876b87fa2509065b:0xaa3f40c998cb5651
# 68358  0x89c2f25ca541dd67:0xe86934186b7b42ce
# 68359  0x876b8762d2aef781:0xf3b2105f4b02f125
# 68360   0x89c2945ee4992e83:0x31a13eefd017247
# 68361  0x89cb9139a319ce21:0x683ec356aa58d6d2
#
#                                              description   latitude  \
# 0                                                   <NA>  32.388300
# 1                                                   <NA>  35.359437
# 2                                                   <NA>  35.236050
# 3                                                   <NA>  30.501326
# 4                                                   <NA>  33.931450
# ...                                                  ...        ...
# 68357                                               <NA>  39.776739
# 68358                                               <NA>  40.916151
# 68359                                               <NA>  39.762645
# 68360                                               <NA>  41.026471
# 68361  Women's clothing chain with fashionable plus-s...  40.486256
#
#         longitude                                           category  \
# 0      -83.357100                                       ['Pharmacy']
# 1      -82.179693                           ['General store', 'ATM']
# 2      -82.351049                                    ['Pet groomer']
# 3      -90.484117                                ['Vaporizer store']
# 4      -84.495418                           ['Medical supply store']
# ...           ...                                                ...
# 68357 -105.043276    ['Optometrist', 'Optician', 'Sunglasses store']
# 68358  -73.899242                               ['Auto repair shop']
# 68359 -105.034395        ['Pet sitter', 'Dog trainer', 'Dog walker']
# 68360  -73.791260                         ['Security guard service']
# 68361  -78.386697  ['Plus size clothing store', 'Clothing store',...
#
#        avg_rating  num_of_reviews price  \
# 0             4.9              16  <NA>
# 1             5.0               4  <NA>
# 2             4.9               8  <NA>
# 3             4.4              57  <NA>
# 4             4.8             228  <NA>
# ...           ...             ...   ...
# 68357         5.0              28  <NA>
# 68358         4.9              18  <NA>
# 68359         5.0               5  <NA>
# 68360         3.6               5  <NA>
# 68361         4.4              41    $$
#
#                                                    hours  \
# 0      [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
# 1      [['Wednesday', '6AM–6PM'], ['Thursday', '6AM–8...
# 2      [['Wednesday', '9:30AM–4:30PM'], ['Thursday', ...
# 3                                                   <NA>
# 4      [['Wednesday', '9AM–12PM'], ['Thursday', '9AM–...
# ...                                                  ...
# 68357  [['Thursday', '10AM–6PM'], ['Friday', '10AM–6P...
# 68358                                               <NA>
# 68359  [['Thursday', '6AM–10PM'], ['Friday', '6AM–10P...
# 68360  [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# 68361  [['Thursday', '10AM–8PM'], ['Friday', '10AM–9P...
#
#                                                     MISC  \
# 0      {'Service options': ['In-store shopping', 'Sam...
# 1      {'Service options': ['In-store shopping', 'Del...
# 2                                                   <NA>
# 3                                                   <NA>
# 4      {'Accessibility': ['Wheelchair accessible entr...
# ...                                                  ...
# 68357  {'Accessibility': ['Wheelchair accessible entr...
# 68358  {'Accessibility': ['Wheelchair accessible entr...
# 68359                                               <NA>
# 68360                                               <NA>
# 68361  {'Service options': ['Curbside pickup', 'In-st...
#
#                         state  \
# 0           Open ⋅ Closes 6PM
# 1      Closed ⋅ Opens 6AM Thu
# 2      Closed ⋅ Opens 9AM Thu
# 3                        <NA>
# 4      Closed ⋅ Opens 9AM Thu
# ...                       ...
# 68357       Open ⋅ Closes 6PM
# 68358                Open now
# 68359      Open ⋅ Closes 10PM
# 68360       Open ⋅ Closes 5PM
# 68361       Open ⋅ Closes 8PM
#
#                                         relative_results  \
# 0      ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
# 1      ['0x88575f0654bd7c03:0x1e5bcb4ee2d6072', '0x88...
# 2      ['0x8859db7e2299101f:0xf71932e69cc2ba14', '0x8...
# 3      ['0x862722eb9415f87d:0xb2b9b86ad30ca06a', '0x8...
# 4      ['0x88f515da59770615:0x3d0ce33a674eded2', '0x8...
# ...                                                  ...
# 68357  ['0x876c7e3a86ff6665:0xad90f0f563ae06e4', '0x8...
# 68358  ['0x89c2f266a9b30f1f:0x3df2675a2f4bdd19', '0x8...
# 68359  ['0x876c7cff89c6822d:0xa31db3899e26aa7e', '0x8...
# 68360  ['0x89c2943625cb3957:0xbfb759238ae9dcb', '0x89...
# 68361  ['0x89cb91396e382079:0xc0205e19a5c92cb8', '0x8...
#
#                                                      url
# 0      https://www.google.com/maps/place//data=!4m2!3...
# 1      https://www.google.com/maps/place//data=!4m2!3...
# 2      https://www.google.com/maps/place//data=!4m2!3...
# 3      https://www.google.com/maps/place//data=!4m2!3...
# 4      https://www.google.com/maps/place//data=!4m2!3...
# ...                                                  ...
# 68357  https://www.google.com/maps/place//data=!4m2!3...
# 68358  https://www.google.com/maps/place//data=!4m2!3...
# 68359  https://www.google.com/maps/place//data=!4m2!3...
# 68360  https://www.google.com/maps/place//data=!4m2!3...
# 68361  https://www.google.com/maps/place//data=!4m2!3...
#
# [3025011 rows x 15 columns]

# %% [markdown]
# ## b. Convierte JSON a JSONL para hacerlo compatible con Google Cloud Platform

# %%
output_file_path = 'G:\My Drive\HENRY\PROYECTO_FINAL\DATASETS\JSONL\metadata_sitios_JSONL.jsonl'

metadata_sitios.to_json(output_file_path, orient='records', lines=True)

# %%
metadata_sitios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3025011 entries, 0 to 3025010
# Data columns (total 15 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   name              string
#  1   address           string
#  2   gmap_id           string
#  3   description       string
#  4   latitude          float64
#  5   longitude         float64
#  6   category          string
#  7   avg_rating        float64
#  8   num_of_reviews    int64
#  9   price             string
#  10  hours             string
#  11  MISC              string
#  12  state             string
#  13  relative_results  string
#  14  url               string
# dtypes: float64(3), int64(1), string(11)
# memory usage: 346.2 MB

# %%
print(metadata_sitios.head())
# Out:
#                name                                            address  \
# 0   Porter Pharmacy  Porter Pharmacy, 129 N Second St, Cochran, GA ...
# 1      City Textile  City Textile, 3001 E Pico Blvd, Los Angeles, C...
# 2      San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3      Nova Fabrics  Nova Fabrics, 2200 E 11th St, Los Angeles, CA ...
# 4  Nobel Textile Co  Nobel Textile Co, 719 E 9th St, Los Angeles, C...
#
#                                  gmap_id description   latitude   longitude  \
# 0  0x88f16e41928ff687:0x883dad4fd048e8f8        <NA>  32.388300  -83.357100
# 1  0x80c2c98c0e3c16fd:0x29ec8a728764fdf9        <NA>  34.018891 -118.215290
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        <NA>  34.058092 -118.292130
# 3   0x80c2c89923b27a41:0x32041559418d447        <NA>  34.023669 -118.232930
# 4  0x80c2c632f933b073:0xc31785961fe826a6        <NA>  34.036694 -118.249421
#
#                 category  avg_rating  num_of_reviews price  \
# 0           ['Pharmacy']         4.9              16  <NA>
# 1   ['Textile exporter']         4.5               6  <NA>
# 2  ['Korean restaurant']         4.4              18  <NA>
# 3       ['Fabric store']         3.3               6  <NA>
# 4       ['Fabric store']         4.3               7  <NA>
#
#                                                hours  \
# 0  [['Friday', '8AM–6PM'], ['Saturday', '8AM–12PM...
# 1                                               <NA>
# 2  [['Thursday', '6:30AM–6PM'], ['Friday', '6:30A...
# 3  [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
# 4  [['Thursday', '9AM–5PM'], ['Friday', '9AM–5PM'...
#
#                                                 MISC              state  \
# 0  {'Service options': ['In-store shopping', 'Sam...  Open ⋅ Closes 6PM
# 1                                               <NA>           Open now
# 2  {'Service options': ['Takeout', 'Dine-in', 'De...  Open ⋅ Closes 6PM
# 3  {'Service options': ['In-store shopping'], 'Pa...  Open ⋅ Closes 5PM
# 4           {'Service options': ['In-store pickup']}  Open ⋅ Closes 5PM
#
#                                     relative_results  \
# 0  ['0x88f16e41929435cf:0x5b2532a2885e9ef6', '0x8...
# 1  ['0x80c2c624136ea88b:0xb0315367ed448771', '0x8...
# 2  ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
# 3  ['0x80c2c8811477253f:0x23a8a492df1918f7', '0x8...
# 4  ['0x80c2c62c496083d1:0xdefa11317fe870a1', '0x8...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %% [markdown]
# ## c. Segmenta por ubicación geográfica
# Una vez hecho la segmentación, el nuevo dataset contiene 75,815 registros.

# %%
# Cargar el archivo geojson que contiene los límites geográficos del condado de Los Angeles
gdf = gpd.read_file(r'G:\My Drive\HENRY\PROYECTO_FINAL\DATASETS\GEOJSON\Los_Angeles_polygon.geojson')

# Obtiene la primera geometría del archivo geojson
los_angeles_polygon = gdf['geometry'].iloc[0]

# Función para verificar si un punto (latitud, longitud) está dentro del polígono de Los Angeles County
def point_within_polygon(lat, lon, polygon):
    point = Point(lon, lat)
    return point.within(polygon)

# Aplicar la función para filtrar el DataFrame metadata_sitios, crea una nueva columna "within_la_county"
# para indicar si el regitro está o no (True/False) dentro del condado de Los Angeles
metadata_sitios['within_la_county'] = metadata_sitios.apply(lambda row: point_within_polygon(row['latitude'], row['longitude'], los_angeles_polygon), axis=1)

# Filtrar el DataFrame por puntos dentro del polígono de Los Angeles County (within_la_county = True)
la_county_df = metadata_sitios[metadata_sitios['within_la_county']]

# Mostrar el DataFrame resultante
print(la_county_df)
# Out:
#                                     name  \
# 323                          Blaze Pizza
# 328                           Which Wich
# 340            Hollywood Star Smog Check
# 344                                Quibi
# 369                    Wonder View Trail
# ...                                  ...
# 67829  Oceana Day Spa Asian Massage Open
# 67830                Moonlight Skin Care
# 68101                      Panda Express
# 68245              Hemangini Beauty Care
# 68246                    Generation Cuts
#
#                                                  address  \
# 323    Blaze Pizza, 6290 Sunset Blvd #1b, Hollywood, ...
# 328    Which Wich, 5529 Hollywood Blvd, Los Angeles, ...
# 340    Hollywood Star Smog Check, 5600 Franklin Ave, ...
# 344        Quibi, 6555 Barton Ave, Los Angeles, CA 90038
# 369             Wonder View Trail, Los Angeles, CA 90068
# ...                                                  ...
# 67829  Oceana Day Spa Asian Massage Open, 238 Cherry ...
# 67830  Moonlight Skin Care, 2942 E Anaheim St, Long B...
# 68101  Panda Express, 1000 Universal Terrace Pkwy, Un...
# 68245  Hemangini Beauty Care, 9039 Reseda Blvd, North...
# 68246  Generation Cuts, 20050 Vanowen S. #E, Winnetka...
#
#                                      gmap_id  \
# 323     0x80c2bf292328759b:0xa4cc48e9b13e0b4
# 328    0x80c2bf731d4eba4d:0xefbda3777d10f565
# 340    0x80c2bfbd8911f381:0x68388cae12b2665b
# 344    0x80c2bf16910f67f1:0xeec928e130f3c9a6
# 369    0x80c2bfa4fc5fd2af:0x60f8d9a413224258
# ...                                      ...
# 67829  0x80dd31059ef9a455:0x132ee40a835ac02c
# 67830  0x80dd319f912a5971:0x9e2a723932ff6441
# 68101  0x80c2bf076d27477f:0x63eb460011ee6822
# 68245  0x80c29a5326ac1bcb:0xb3da18d04e813b2a
# 68246  0x80c29ca3acce8641:0x9f7bd7628d4837bf
#
#                                              description   latitude  \
# 323    Hip counter-serve pizzeria dishing up crispy, ...  34.097840
# 328    Modern, casual chain known for design-your-own...  34.101883
# 340                                                 <NA>  34.105098
# 344                                                 <NA>  34.087947
# 369                                                 <NA>  34.136090
# ...                                                  ...        ...
# 67829                                               <NA>  33.767568
# 67830                                               <NA>  33.782211
# 68101  Fast-food chain for Chinese standards, includi...  34.137175
# 68245                                               <NA>  34.234771
# 68246                                               <NA>  34.193503
#
#         longitude                                           category  \
# 323   -118.326311  ['Pizza restaurant', 'Family restaurant', 'Piz...
# 328   -118.310251                                     ['Restaurant']
# 340   -118.310983                        ['Smog inspection station']
# 344   -118.334826                                  ['Media company']
# 369   -118.329986                                               <NA>
# ...           ...                                                ...
# 67829 -118.167656  ['Massage therapist', 'Day spa', 'Foot massage...
# 67830 -118.157205                              ['Massage therapist']
# 68101 -118.352199                             ['Chinese restaurant']
# 68245 -118.536394                                   ['Beauty salon']
# 68246 -118.570451                                    ['Barber shop']
#
#        avg_rating  num_of_reviews price  \
# 323           4.0              68     $
# 328           4.7              18     $
# 340           4.6              27  <NA>
# 344           5.0               5  <NA>
# 369           5.0               1  <NA>
# ...           ...             ...   ...
# 67829         4.2              15  <NA>
# 67830         4.3               8  <NA>
# 68101         4.3               5     $
# 68245         4.7              58  <NA>
# 68246         4.8              55  <NA>
#
#                                                    hours  \
# 323    [['Wednesday', '10:30AM–10PM'], ['Thursday', '...
# 328    [['Wednesday', '11AM–9PM'], ['Thursday', '11AM...
# 340    [['Wednesday', '8AM–6PM'], ['Thursday', '8AM–6...
# 344                                                 <NA>
# 369                                                 <NA>
# ...                                                  ...
# 67829  [['Thursday', '10AM–9:30PM'], ['Friday', '10AM...
# 67830  [['Thursday', '10AM–9PM'], ['Friday', '10AM–9P...
# 68101  [['Thursday', '12–8PM'], ['Friday', '12–8PM'],...
# 68245  [['Thursday', '10AM–7PM'], ['Friday', '10AM–7P...
# 68246  [['Thursday', '10AM–7PM'], ['Friday', '10AM–7P...
#
#                                                     MISC  \
# 323    {'Service options': ['Outdoor seating', 'No-co...
# 328    {'Service options': ['No-contact delivery', 'D...
# 340                                                 <NA>
# 344                                                 <NA>
# 369                                                 <NA>
# ...                                                  ...
# 67829  {'From the business': ['Identifies as women-le...
# 67830  {'Accessibility': ['Wheelchair accessible entr...
# 68101  {'Service options': ['Takeout', 'Delivery'], '...
# 68245  {'Accessibility': ['Wheelchair accessible entr...
# 68246  {'Health & safety': ['Appointment required', '...
#
#                       state  \
# 323      Open ⋅ Closes 10PM
# 328       Open ⋅ Closes 9PM
# 340       Open ⋅ Closes 6PM
# 344                    <NA>
# 369                    <NA>
# ...                     ...
# 67829  Open ⋅ Closes 9:30PM
# 67830     Open ⋅ Closes 9PM
# 68101     Opens soon ⋅ 12PM
# 68245     Open ⋅ Closes 7PM
# 68246     Open ⋅ Closes 7PM
#
#                                         relative_results  \
# 323    ['0x80c2bf4828e4791d:0xed03b6c09953517c', '0x8...
# 328                                                 <NA>
# 340    ['0x80c2bf4f81a7e241:0x5b7aa7546ecb3152', '0x8...
# 344                                                 <NA>
# 369                                                 <NA>
# ...                                                  ...
# 67829  ['0x80dd310bf7bcaa01:0x9aa76506d63b06da', '0x8...
# 67830  ['0x80dd31bd38e43e79:0x4ac4d5b20f252944', '0x8...
# 68101  ['0x80c2be4f8e86892f:0x1e599a6515906f16', '0x8...
# 68245  ['0x80c29a1d9825ca9b:0x28ea672de7140cc0', '0x8...
# 68246  ['0x80c29bfc5d22e033:0x6034e3f38155f3c', '0x80...
#
#                                                      url  within_la_county
# 323    https://www.google.com/maps/place//data=!4m2!3...              True
# 328    https://www.google.com/maps/place//data=!4m2!3...              True
# 340    https://www.google.com/maps/place//data=!4m2!3...              True
# 344    https://www.google.com/maps/place//data=!4m2!3...              True
# 369    https://www.google.com/maps/place/Los+Angeles,...              True
# ...                                                  ...               ...
# 67829  https://www.google.com/maps/place//data=!4m2!3...              True
# 67830  https://www.google.com/maps/place//data=!4m2!3...              True
# 68101  https://www.google.com/maps/place//data=!4m2!3...              True
# 68245  https://www.google.com/maps/place//data=!4m2!3...              True
# 68246  https://www.google.com/maps/place//data=!4m2!3...              True
#
# [75815 rows x 16 columns]

# %%
la_county_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75815 entries, 1 to 3024752
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              75815 non-null  string
#  1   address           74729 non-null  string
#  2   gmap_id           75815 non-null  string
#  3   description       8890 non-null   string
#  4   latitude          75815 non-null  float64
#  5   longitude         75815 non-null  float64
#  6   category          75319 non-null  string
#  7   avg_rating        75815 non-null  float64
#  8   num_of_reviews    75815 non-null  int64
#  9   price             8415 non-null   string
#  10  hours             60190 non-null  string
#  11  MISC              60945 non-null  string
#  12  state             60905 non-null  string
#  13  relative_results  69352 non-null  string
#  14  url               75815 non-null  string
#  15  within_la_county  75815 non-null  bool
# dtypes: bool(1), float64(3), int64(1), string(11)
# memory usage: 9.3 MB

# %% [markdown]
# ## d. Prepara el campo "category" para la siguiente segmentación
# <a id="sección-4-Frecuencias-category-name"></a>

# %%
''' Se observa que el campo "category" contiene listas y en algunos casos, listas de listas; sin embargo, el tipo de dato en este campo está definido como STRING, por lo que antes de explotarlo hay que convertilo a listas'''
# Función para asegurar que todos los elementos sean listas
def ensure_list(x):
    if isinstance(x, str):
        # Intenta convertir una cadena que parece una lista en una lista real
        try:
            return ast.literal_eval(x)
        except (ValueError, SyntaxError):
            return [x]
    elif not isinstance(x, list):
        return [x]
    return x

# Aplicar la función para asegurar que todos los elementos son listas
la_county_df['category'] = la_county_df['category'].apply(ensure_list)

# Verificar nuevamente los tipos después de la conversión
print(la_county_df['category'].apply(type).unique())

# Función para explotar completamente una columna específica
def fully_explode_column(df, column):
    while df[column].apply(lambda x: isinstance(x, list)).any():
        df = df.explode(column)
    return df

# Aplicar la función a la columna 'category'
df_exploded = fully_explode_column(la_county_df, 'category')

# Mostrar el DataFrame con la columna 'category' completamente explotada
print(df_exploded)
# Out:
# [<class 'list'>]
#                                     name  \
# 323                          Blaze Pizza
# 323                          Blaze Pizza
# 323                          Blaze Pizza
# 328                           Which Wich
# 340            Hollywood Star Smog Check
# ...                                  ...
# 67829  Oceana Day Spa Asian Massage Open
# 67830                Moonlight Skin Care
# 68101                      Panda Express
# 68245              Hemangini Beauty Care
# 68246                    Generation Cuts
#
#                                                  address  \
# 323    Blaze Pizza, 6290 Sunset Blvd #1b, Hollywood, ...
# 323    Blaze Pizza, 6290 Sunset Blvd #1b, Hollywood, ...
# 323    Blaze Pizza, 6290 Sunset Blvd #1b, Hollywood, ...
# 328    Which Wich, 5529 Hollywood Blvd, Los Angeles, ...
# 340    Hollywood Star Smog Check, 5600 Franklin Ave, ...
# ...                                                  ...
# 67829  Oceana Day Spa Asian Massage Open, 238 Cherry ...
# 67830  Moonlight Skin Care, 2942 E Anaheim St, Long B...
# 68101  Panda Express, 1000 Universal Terrace Pkwy, Un...
# 68245  Hemangini Beauty Care, 9039 Reseda Blvd, North...
# 68246  Generation Cuts, 20050 Vanowen S. #E, Winnetka...
#
#                                      gmap_id  \
# 323     0x80c2bf292328759b:0xa4cc48e9b13e0b4
# 323     0x80c2bf292328759b:0xa4cc48e9b13e0b4
# 323     0x80c2bf292328759b:0xa4cc48e9b13e0b4
# 328    0x80c2bf731d4eba4d:0xefbda3777d10f565
# 340    0x80c2bfbd8911f381:0x68388cae12b2665b
# ...                                      ...
# 67829  0x80dd31059ef9a455:0x132ee40a835ac02c
# 67830  0x80dd319f912a5971:0x9e2a723932ff6441
# 68101  0x80c2bf076d27477f:0x63eb460011ee6822
# 68245  0x80c29a5326ac1bcb:0xb3da18d04e813b2a
# 68246  0x80c29ca3acce8641:0x9f7bd7628d4837bf
#
#                                              description   latitude  \
# 323    Hip counter-serve pizzeria dishing up crispy, ...  34.097840
# 323    Hip counter-serve pizzeria dishing up crispy, ...  34.097840
# 323    Hip counter-serve pizzeria dishing up crispy, ...  34.097840
# 328    Modern, casual chain known for design-your-own...  34.101883
# 340                                                 <NA>  34.105098
# ...                                                  ...        ...
# 67829                                               <NA>  33.767568
# 67830                                               <NA>  33.782211
# 68101  Fast-food chain for Chinese standards, includi...  34.137175
# 68245                                               <NA>  34.234771
# 68246                                               <NA>  34.193503
#
#         longitude                     category  avg_rating  num_of_reviews  \
# 323   -118.326311             Pizza restaurant         4.0              68
# 323   -118.326311            Family restaurant         4.0              68
# 323   -118.326311                Pizza Takeout         4.0              68
# 328   -118.310251                   Restaurant         4.7              18
# 340   -118.310983      Smog inspection station         4.6              27
# ...           ...                          ...         ...             ...
# 67829 -118.167656  Waxing hair removal service         4.2              15
# 67830 -118.157205            Massage therapist         4.3               8
# 68101 -118.352199           Chinese restaurant         4.3               5
# 68245 -118.536394                 Beauty salon         4.7              58
# 68246 -118.570451                  Barber shop         4.8              55
#
#       price                                              hours  \
# 323       $  [['Wednesday', '10:30AM–10PM'], ['Thursday', '...
# 323       $  [['Wednesday', '10:30AM–10PM'], ['Thursday', '...
# 323       $  [['Wednesday', '10:30AM–10PM'], ['Thursday', '...
# 328       $  [['Wednesday', '11AM–9PM'], ['Thursday', '11AM...
# 340    <NA>  [['Wednesday', '8AM–6PM'], ['Thursday', '8AM–6...
# ...     ...                                                ...
# 67829  <NA>  [['Thursday', '10AM–9:30PM'], ['Friday', '10AM...
# 67830  <NA>  [['Thursday', '10AM–9PM'], ['Friday', '10AM–9P...
# 68101     $  [['Thursday', '12–8PM'], ['Friday', '12–8PM'],...
# 68245  <NA>  [['Thursday', '10AM–7PM'], ['Friday', '10AM–7P...
# 68246  <NA>  [['Thursday', '10AM–7PM'], ['Friday', '10AM–7P...
#
#                                                     MISC  \
# 323    {'Service options': ['Outdoor seating', 'No-co...
# 323    {'Service options': ['Outdoor seating', 'No-co...
# 323    {'Service options': ['Outdoor seating', 'No-co...
# 328    {'Service options': ['No-contact delivery', 'D...
# 340                                                 <NA>
# ...                                                  ...
# 67829  {'From the business': ['Identifies as women-le...
# 67830  {'Accessibility': ['Wheelchair accessible entr...
# 68101  {'Service options': ['Takeout', 'Delivery'], '...
# 68245  {'Accessibility': ['Wheelchair accessible entr...
# 68246  {'Health & safety': ['Appointment required', '...
#
#                       state  \
# 323      Open ⋅ Closes 10PM
# 323      Open ⋅ Closes 10PM
# 323      Open ⋅ Closes 10PM
# 328       Open ⋅ Closes 9PM
# 340       Open ⋅ Closes 6PM
# ...                     ...
# 67829  Open ⋅ Closes 9:30PM
# 67830     Open ⋅ Closes 9PM
# 68101     Opens soon ⋅ 12PM
# 68245     Open ⋅ Closes 7PM
# 68246     Open ⋅ Closes 7PM
#
#                                         relative_results  \
# 323    ['0x80c2bf4828e4791d:0xed03b6c09953517c', '0x8...
# 323    ['0x80c2bf4828e4791d:0xed03b6c09953517c', '0x8...
# 323    ['0x80c2bf4828e4791d:0xed03b6c09953517c', '0x8...
# 328                                                 <NA>
# 340    ['0x80c2bf4f81a7e241:0x5b7aa7546ecb3152', '0x8...
# ...                                                  ...
# 67829  ['0x80dd310bf7bcaa01:0x9aa76506d63b06da', '0x8...
# 67830  ['0x80dd31bd38e43e79:0x4ac4d5b20f252944', '0x8...
# 68101  ['0x80c2be4f8e86892f:0x1e599a6515906f16', '0x8...
# 68245  ['0x80c29a1d9825ca9b:0x28ea672de7140cc0', '0x8...
# 68246  ['0x80c29bfc5d22e033:0x6034e3f38155f3c', '0x80...
#
#                                                      url  within_la_county
# 323    https://www.google.com/maps/place//data=!4m2!3...              True
# 323    https://www.google.com/maps/place//data=!4m2!3...              True
# 323    https://www.google.com/maps/place//data=!4m2!3...              True
# 328    https://www.google.com/maps/place//data=!4m2!3...              True
# 340    https://www.google.com/maps/place//data=!4m2!3...              True
# ...                                                  ...               ...
# 67829  https://www.google.com/maps/place//data=!4m2!3...              True
# 67830  https://www.google.com/maps/place//data=!4m2!3...              True
# 68101  https://www.google.com/maps/place//data=!4m2!3...              True
# 68245  https://www.google.com/maps/place//data=!4m2!3...              True
# 68246  https://www.google.com/maps/place//data=!4m2!3...              True
#
# [151515 rows x 16 columns]
# C:\Users\occar\AppData\Local\Temp\ipykernel_28384\2553266023.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   la_county_df['category'] = la_county_df['category'].apply(ensure_list)

# %% [markdown]
# ## e. Segmenta los comercios de Los Ángeles, conserva solo los restaurantes
# <a id="sección-6-top10-negocios-categorias"></a>

# %%
# Para poder aplicar el fitro por tipo de reubro (category) es necesario eliminar los valores nulos.

# Elimina las 496 filas con valores nulos en el campo de category (representan el 0.3% del dataset df_exploded)
google_restaurants_la = df_exploded.dropna(subset=['category'])

# Elimina la columna 'within_la_county' porque ya no se necesita
google_restaurants_la = google_restaurants_la.drop(columns= 'within_la_county')

# Filtrar el DataFrame para incluir solo filas donde 'category' contiene la palabra 'restaurant' (ignorar mayúsculas/minúsculas)
google_restaurants_la = google_restaurants_la[google_restaurants_la['category'].str.contains('restaurant', case=False, regex=True)]


# Mostrar el DataFrame resultante posee 13,955 registros (Restaurantes en el condado de Los Angeles)
google_restaurants_la.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13955 entries, 323 to 68101
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              13955 non-null  string
#  1   address           13918 non-null  string
#  2   gmap_id           13955 non-null  string
#  3   description       6668 non-null   string
#  4   latitude          13955 non-null  float64
#  5   longitude         13955 non-null  float64
#  6   category          13955 non-null  object
#  7   avg_rating        13955 non-null  float64
#  8   num_of_reviews    13955 non-null  int64
#  9   price             8355 non-null   string
#  10  hours             13064 non-null  string
#  11  MISC              13902 non-null  string
#  12  state             13070 non-null  string
#  13  relative_results  11874 non-null  string
#  14  url               13955 non-null  string
# dtypes: float64(3), int64(1), object(1), string(10)
# memory usage: 14.4+ MB

# %% [markdown]
# # 3. Relaciona el data set de reviews de California (reviews_california) con el de sitios (ambos de Google Maps)

# %%
# Define la ruta de la carpeta principal donde se encuentran los archivos JSON (18 archivos)
main_folder = r'G:\My Drive\HENRY\PROYECTO_FINAL\ORIGINALES\GoogleMaps_local\Google Maps\reviews-estados\review-California'

# Busca todos los archivos JSON en la carpeta principal y subcarpetas
all_json_files = glob.glob(os.path.join(main_folder, '**', '*.json'), recursive=True)

# Lista para almacenar los DataFrames
dataframes = []

# Función para leer y procesar archivos JSON
def read_json_file(file_path):
    data = []
    try:
        with open(file_path, 'r') as file:
            content = file.read()
            # Intenta cargar todo el contenido del archivo como un solo objeto JSON
            try:
                data = json.loads(content)
                if not isinstance(data, list):
                    data = [data]
            except json.JSONDecodeError:
                # Si falla, intenta cargar línea por línea
                lines = content.splitlines()
                for line in lines:
                    try:
                        data.append(json.loads(line))
                    except json.JSONDecodeError:
                        continue
    except Exception as e:
        print(f"Error reading file {file_path}, error: {e}")
    return data

# Leer y cargar cada archivo JSON en un DataFrame de pandas
for json_file in all_json_files:
    data = read_json_file(json_file)
    if data:
        df = pd.DataFrame(data)
        dataframes.append(df)

# Combinar todos los DataFrames en uno solo (opcional, si es que tienen la misma estructura)
combined_df = pd.concat(dataframes, ignore_index=True)

# Mostrar el DataFrame combinado
print(combined_df)
# Out:
#                        user_id                  name           time  rating  \
# 0        115274425309166773614          Stephen Hall  1570134566324       5
# 1        116695856577336408669        Qatt Flyingcat  1551616611864       4
# 2        109886017994331646459         Evan Frangesh  1572397745364       4
# 3        101966003638483326769          Bilal Tunuli  1604442623462       5
# 4        107683806161097684473          Hafeesa Lane  1620418756293       5
# ...                        ...                   ...            ...     ...
# 2699995  108193947284587444903  Raffi Khatchadourian  1583646462958       5
# 2699996  107576150927112175851     Noah Vincent Ford  1605055631573       5
# 2699997  100811264799703254415        David Karwaski  1597443113544       5
# 2699998  117707797007071438468       Reynalda Vargaz  1573479297751       5
# 2699999  108938090607306166613             Omid Hass  1601598200197       5
#
#                                                       text  pics  resp  \
# 0                                                     None  None  None
# 1                                                     None  None  None
# 2                                                     None  None  None
# 3                                                     None  None  None
# 4        Best food around! Pad Thai is my absolute favo...  None  None
# ...                                                    ...   ...   ...
# 2699995                                               None  None  None
# 2699996                                               None  None  None
# 2699997                                               None  None  None
# 2699998                                               None  None  None
# 2699999                                               None  None  None
#
#                                        gmap_id
# 0        0x80dcd75f928a1c49:0x8dd959cb87891917
# 1        0x80dcd75f928a1c49:0x8dd959cb87891917
# 2        0x80dcd75f928a1c49:0x8dd959cb87891917
# 3        0x80dcd75f928a1c49:0x8dd959cb87891917
# 4        0x80945da7eabb696d:0x7e1e38d45e7a2637
# ...                                        ...
# 2699995  0x80c299484c7709cd:0x89510434231b14d4
# 2699996  0x80c299484c7709cd:0x89510434231b14d4
# 2699997  0x80c299484c7709cd:0x89510434231b14d4
# 2699998  0x80c299484c7709cd:0x89510434231b14d4
# 2699999  0x80c299484c7709cd:0x89510434231b14d4
#
# [2700000 rows x 8 columns]

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2700000 entries, 0 to 2699999
# Data columns (total 8 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  object
#  1   name     object
#  2   time     int64
#  3   rating   int64
#  4   text     object
#  5   pics     object
#  6   resp     object
#  7   gmap_id  object
# dtypes: int64(2), object(6)
# memory usage: 164.8+ MB

# %%
combined_df.head()
# Out:
#                  user_id           name           time  rating  \
# 0  108991152262655788985        Song Ro  1609909927056       5
# 1  111290322219796215751    Rafa Robles  1612849648663       5
# 2  112640357449611959087      David Han  1583643882296       4
# 3  117440349723823658676    Anthony Kim  1551938216355       5
# 4  100580770836123539210  Mario Marzouk  1494910901933       5
#
#                                                text  pics  resp  \
# 0                      Love there korean rice cake.  None  None
# 1                                    Good very good  None  None
# 2  They make Korean traditional food very properly.  None  None
# 3                    Short ribs are very delicious.  None  None
# 4      Great food and prices the portions are large  None  None
#
#                                  gmap_id
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 3  0x80c2c778e3b73d33:0xbdc58662a4a97d49
# 4  0x80c2c778e3b73d33:0xbdc58662a4a97d49

# %%
# Realizar la unión de los DataFrames en el campo 'gmap_id'
gmap_meta_reviews = pd.merge(google_restaurants_la, combined_df, on='gmap_id', how='inner')

# Mostrar el DataFrame resultante
gmap_meta_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517513 entries, 0 to 517512
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   name_x            517513 non-null  string
#  1   address           517513 non-null  string
#  2   gmap_id           517513 non-null  object
#  3   description       424501 non-null  string
#  4   latitude          517513 non-null  float64
#  5   longitude         517513 non-null  float64
#  6   category          517513 non-null  object
#  7   avg_rating        517513 non-null  float64
#  8   num_of_reviews    517513 non-null  int64
#  9   price             460548 non-null  string
#  10  hours             506538 non-null  string
#  11  MISC              517392 non-null  string
#  12  state             506737 non-null  string
#  13  relative_results  503399 non-null  string
#  14  url               517513 non-null  string
#  15  user_id           517513 non-null  object
#  16  name_y            517513 non-null  object
#  17  time              517513 non-null  int64
#  18  rating            517513 non-null  int64
#  19  text              287086 non-null  object
#  20  pics              19437 non-null   object
#  21  resp              29885 non-null   object
# dtypes: float64(3), int64(3), object(7), string(9)
# memory usage: 690.3+ MB

# %%
gmap_meta_reviews.head()
# Out:
#          name_x                                            address  \
# 0  San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 1  San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 2  San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 3  San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
# 4  San Soo Dang  San Soo Dang, 761 S Vermont Ave, Los Angeles, ...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x80c2c778e3b73d33:0xbdc58662a4a97d49        <NA>  34.058092 -118.29213
# 1  0x80c2c778e3b73d33:0xbdc58662a4a97d49        <NA>  34.058092 -118.29213
# 2  0x80c2c778e3b73d33:0xbdc58662a4a97d49        <NA>  34.058092 -118.29213
# 3  0x80c2c778e3b73d33:0xbdc58662a4a97d49        <NA>  34.058092 -118.29213
# 4  0x80c2c778e3b73d33:0xbdc58662a4a97d49        <NA>  34.058092 -118.29213
#
#             category  avg_rating  num_of_reviews price  ...  \
# 0  Korean restaurant         4.4              18  <NA>  ...
# 1  Korean restaurant         4.4              18  <NA>  ...
# 2  Korean restaurant         4.4              18  <NA>  ...
# 3  Korean restaurant         4.4              18  <NA>  ...
# 4  Korean restaurant         4.4              18  <NA>  ...
#
#                state                                   relative_results  \
# 0  Open ⋅ Closes 6PM  ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
# 1  Open ⋅ Closes 6PM  ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
# 2  Open ⋅ Closes 6PM  ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
# 3  Open ⋅ Closes 6PM  ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
# 4  Open ⋅ Closes 6PM  ['0x80c2c78249aba68f:0x35bf16ce61be751d', '0x8...
#
#                                                  url                user_id  \
# 0  https://www.google.com/maps/place//data=!4m2!3...  108991152262655788985
# 1  https://www.google.com/maps/place//data=!4m2!3...  111290322219796215751
# 2  https://www.google.com/maps/place//data=!4m2!3...  112640357449611959087
# 3  https://www.google.com/maps/place//data=!4m2!3...  117440349723823658676
# 4  https://www.google.com/maps/place//data=!4m2!3...  100580770836123539210
#
#           name_y           time rating  \
# 0        Song Ro  1609909927056      5
# 1    Rafa Robles  1612849648663      5
# 2      David Han  1583643882296      4
# 3    Anthony Kim  1551938216355      5
# 4  Mario Marzouk  1494910901933      5
#
#                                                text  pics  resp
# 0                      Love there korean rice cake.  None  None
# 1                                    Good very good  None  None
# 2  They make Korean traditional food very properly.  None  None
# 3                    Short ribs are very delicious.  None  None
# 4      Great food and prices the portions are large  None  None
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Imputa valores nulos del campo "reviews" a través de una clasificación brindada por las valoraciones ("avg_rating")

# %%
# Definir la función para imputar valores en el campo 'text' basado en 'avg_rating'
def imputar_texto(row):
    if pd.isnull(row['text']):
        if 1 <= row['avg_rating'] <= 2.9:
            return 'Negative'
        elif 3 <= row['avg_rating'] <= 3.9:
            return 'Neutral'
        elif 4 <= row['avg_rating'] <= 5:
            return 'Positive'
    return row['text']

# Aplicar la función al DataFrame
gmap_meta_reviews['text'] = gmap_meta_reviews.apply(imputar_texto, axis=1)

# Confirma que todos los registros nulos del campo "category" han sido imputados
nulos = gmap_meta_reviews.isnull().sum()
porcentaje = (metadata_sitios.isnull().sum() / len(metadata_sitios)) * 100

# Crear un DataFrame con los resultados
reporte_nulos = pd.DataFrame({'Valores Nulos': nulos, 'Porcentaje': porcentaje})

print(reporte_nulos)
# Out:
#                   Valores Nulos  Porcentaje
# MISC                      121.0   22.837405
# address                     0.0    2.661511
# avg_rating                  0.0    0.000000
# category                    0.0    0.575833
# description             93012.0   91.593783
# gmap_id                     0.0    0.000000
# hours                   10975.0   26.029823
# latitude                    0.0    0.000000
# longitude                   0.0    0.000000
# name                        NaN    0.001223
# name_x                      0.0         NaN
# name_y                      0.0         NaN
# num_of_reviews              0.0    0.000000
# pics                   498076.0         NaN
# price                   56965.0   90.902413
# rating                      0.0         NaN
# relative_results        14114.0    9.753948
# resp                   487628.0         NaN
# state                   10776.0   24.676109
# text                        0.0         NaN
# time                        0.0         NaN
# url                         0.0    0.000000
# user_id                     0.0         NaN
# within_la_county            NaN    0.000000

# %% [markdown]
# ## Transforma el formato de la columna time (timestamp)

# %%
# Convertir la columna de timestamps a un formato legible, asumiendo que está en milisegundos
gmap_meta_reviews['time'] = pd.to_datetime(gmap_meta_reviews['time'], unit='ms')

# En este punto, el archivo ya está listo para ser utilizado en las siguientes fases del proceso
print(gmap_meta_reviews)
# Out:
#                       name_x  \
# 0          Padrinos Taqueria
# 1          Padrinos Taqueria
# 2          Padrinos Taqueria
# 3          Padrinos Taqueria
# 4          Padrinos Taqueria
# ...                      ...
# 517508  Pancho's Tacos Truck
# 517509  Pancho's Tacos Truck
# 517510  Pancho's Tacos Truck
# 517511  Pancho's Tacos Truck
# 517512  Pancho's Tacos Truck
#
#                                                   address  \
# 0       Padrinos Taqueria, 15214 Hawthorne Blvd, Lawnd...
# 1       Padrinos Taqueria, 15214 Hawthorne Blvd, Lawnd...
# 2       Padrinos Taqueria, 15214 Hawthorne Blvd, Lawnd...
# 3       Padrinos Taqueria, 15214 Hawthorne Blvd, Lawnd...
# 4       Padrinos Taqueria, 15214 Hawthorne Blvd, Lawnd...
# ...                                                   ...
# 517508  Pancho's Tacos Truck, Magnolia & Anaheim NE, L...
# 517509  Pancho's Tacos Truck, Magnolia & Anaheim NE, L...
# 517510  Pancho's Tacos Truck, Magnolia & Anaheim NE, L...
# 517511  Pancho's Tacos Truck, Magnolia & Anaheim NE, L...
# 517512  Pancho's Tacos Truck, Magnolia & Anaheim NE, L...
#
#                                       gmap_id description   latitude  \
# 0       0x80c2b57664872891:0xa4a29ec547fcbbfe        <NA>  33.893084
# 1       0x80c2b57664872891:0xa4a29ec547fcbbfe        <NA>  33.893084
# 2       0x80c2b57664872891:0xa4a29ec547fcbbfe        <NA>  33.893084
# 3       0x80c2b57664872891:0xa4a29ec547fcbbfe        <NA>  33.893084
# 4       0x80c2b57664872891:0xa4a29ec547fcbbfe        <NA>  33.893084
# ...                                       ...         ...        ...
# 517508  0x80dd31b13878d737:0x57465a2fc899a15a        <NA>  33.782759
# 517509  0x80dd31b13878d737:0x57465a2fc899a15a        <NA>  33.782759
# 517510  0x80dd31b13878d737:0x57465a2fc899a15a        <NA>  33.782759
# 517511  0x80dd31b13878d737:0x57465a2fc899a15a        <NA>  33.782759
# 517512  0x80dd31b13878d737:0x57465a2fc899a15a        <NA>  33.782759
#
#          longitude            category  avg_rating  num_of_reviews price  ...  \
# 0      -118.351868  Mexican restaurant         4.7              13  <NA>  ...
# 1      -118.351868  Mexican restaurant         4.7              13  <NA>  ...
# 2      -118.351868  Mexican restaurant         4.7              13  <NA>  ...
# 3      -118.351868  Mexican restaurant         4.7              13  <NA>  ...
# 4      -118.351868  Mexican restaurant         4.7              13  <NA>  ...
# ...            ...                 ...         ...             ...   ...  ...
# 517508 -118.197843  Mexican restaurant         4.1              18  <NA>  ...
# 517509 -118.197843  Mexican restaurant         4.1              18  <NA>  ...
# 517510 -118.197843  Mexican restaurant         4.1              18  <NA>  ...
# 517511 -118.197843  Mexican restaurant         4.1              18  <NA>  ...
# 517512 -118.197843  Mexican restaurant         4.1              18  <NA>  ...
#
#                         state  \
# 0          Open ⋅ Closes 10PM
# 1          Open ⋅ Closes 10PM
# 2          Open ⋅ Closes 10PM
# 3          Open ⋅ Closes 10PM
# 4          Open ⋅ Closes 10PM
# ...                       ...
# 517508  Closed ⋅ Opens 4:30PM
# 517509  Closed ⋅ Opens 4:30PM
# 517510  Closed ⋅ Opens 4:30PM
# 517511  Closed ⋅ Opens 4:30PM
# 517512  Closed ⋅ Opens 4:30PM
#
#                                          relative_results  \
# 0       ['0x80c2b5ca9295522b:0x98e870fd785f1b04', '0x8...
# 1       ['0x80c2b5ca9295522b:0x98e870fd785f1b04', '0x8...
# 2       ['0x80c2b5ca9295522b:0x98e870fd785f1b04', '0x8...
# 3       ['0x80c2b5ca9295522b:0x98e870fd785f1b04', '0x8...
# 4       ['0x80c2b5ca9295522b:0x98e870fd785f1b04', '0x8...
# ...                                                   ...
# 517508                                               <NA>
# 517509                                               <NA>
# 517510                                               <NA>
# 517511                                               <NA>
# 517512                                               <NA>
#
#                                                       url  \
# 0       https://www.google.com/maps/place//data=!4m2!3...
# 1       https://www.google.com/maps/place//data=!4m2!3...
# 2       https://www.google.com/maps/place//data=!4m2!3...
# 3       https://www.google.com/maps/place//data=!4m2!3...
# 4       https://www.google.com/maps/place//data=!4m2!3...
# ...                                                   ...
# 517508  https://www.google.com/maps/place//data=!4m2!3...
# 517509  https://www.google.com/maps/place//data=!4m2!3...
# 517510  https://www.google.com/maps/place//data=!4m2!3...
# 517511  https://www.google.com/maps/place//data=!4m2!3...
# 517512  https://www.google.com/maps/place//data=!4m2!3...
#
#                       user_id           name_y                    time rating  \
# 0       101466157268927718420       John Smith 2021-03-17 05:24:26.600      5
# 1       108290488827113185244    Reggie Thomas 2021-04-11 06:00:58.747      5
# 2       118190887173604106189            guy g 2020-09-13 14:09:01.190      3
# 3       105867225016504167204    Axel Coronado 2021-03-07 18:39:30.530      5
# 4       113173608650844547426      Alex Pavlov 2019-11-05 04:18:46.188      5
# ...                       ...              ...                     ...    ...
# 517508  113348369257917869720     Avalon Scott 2020-02-27 04:41:57.133      5
# 517509  105849275477630060530     Rafael Lopez 2020-01-14 15:17:48.181      5
# 517510  108542484354689891126       Trevor Yee 2021-06-19 23:37:13.620      5
# 517511  108659468340830346165     Childdan Oun 2020-09-27 05:21:12.503      5
# 517512  109808438552949915981  Marlene Murillo 2020-08-22 04:58:38.725      5
#
#                                                      text  \
# 0       Taco Tuesday is a must here. Delicious fish or...
# 1       They have great food there very delicious nice...
# 2       Ordered Pozoles soup to go. Was told that they...
# 3                                              Great food
# 4                                             Nice people
# ...                                                   ...
# 517508              Best al postor.. definitely come here
# 517509  Best al pastor tacos I’ve ever had. Sliced off...
# 517510                                           Positive
# 517511                                           Positive
# 517512                                           Positive
#
#                                                      pics  resp
# 0       [{'url': ['https://lh5.googleusercontent.com/p...  None
# 1                                                    None  None
# 2                                                    None  None
# 3                                                    None  None
# 4                                                    None  None
# ...                                                   ...   ...
# 517508                                               None  None
# 517509                                               None  None
# 517510                                               None  None
# 517511                                               None  None
# 517512                                               None  None
#
# [517513 rows x 22 columns]
